# %% [markdown]
# ## Read the csv file and find correlation between the columns/features (using df.corr())

# %%
# import required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prequisities

import warnings
warnings.filterwarnings(action='ignore')

# %%
# load the dataset
df= pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 660.0 bytes

# %%
corr = df.corr()

# %%
print(corr)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.983642
# Salary                  0.983642  1.000000

# %%
sns.pairplot(df)

# %%
df.corr().style.background_gradient(cmap='berlin')
# Out:
# <style type="text/css">
# #T_d520c_row0_col0, #T_d520c_row1_col1 {
#   background-color: #ffadad;
#   color: #000000;
# }
# #T_d520c_row0_col1, #T_d520c_row1_col0 {
#   background-color: #9eb0ff;
#   color: #000000;
# }
# </style>
# <table id="T_d520c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d520c_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_d520c_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d520c_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_d520c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d520c_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_d520c_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_d520c_row1_col0" class="data row1 col0" >0.983642</td>
#       <td id="T_d520c_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.corr().style.background_gradient(cmap='vanimo')
# Out:
# <style type="text/css">
# #T_a63d1_row0_col0, #T_a63d1_row1_col1 {
#   background-color: #befda5;
#   color: #000000;
# }
# #T_a63d1_row0_col1, #T_a63d1_row1_col0 {
#   background-color: #ffcdfd;
#   color: #000000;
# }
# </style>
# <table id="T_a63d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a63d1_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_a63d1_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a63d1_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_a63d1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a63d1_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_a63d1_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_a63d1_row1_col0" class="data row1 col0" >0.983642</td>
#       <td id="T_a63d1_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.corr().style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_64087_row0_col0, #T_64087_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_64087_row0_col1, #T_64087_row1_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64087">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64087_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_64087_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64087_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_64087_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_64087_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_64087_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_64087_row1_col0" class="data row1 col0" >0.983642</td>
#       <td id="T_64087_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
