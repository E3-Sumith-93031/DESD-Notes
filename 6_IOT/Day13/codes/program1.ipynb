# %% [markdown]
# ## Read a csv file and add a new column

# %%
# import required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prequisities

import warnings
warnings.filterwarnings(action='ignore')

# %%
# load the dataset
df= pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# ## EDA(Exploratory Data analysis)

# %%
# first five records
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
# last five records
df.tail()
# Out:
#     YearsExperience  Salary
# 28             10.3  122391
# 29             10.5  121872
# 30             11.0  140000
# 31             12.0  155000
# 32             13.0  156000

# %%
# first ten records
df.head(10)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642
# 6              3.0   60150
# 7              3.2   54445
# 8              3.2   64445
# 9              3.7   57189

# %%
# the statistical info about the dataset
df.describe()
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.921212   82760.303030
# std           3.342413   34014.620992
# min           1.100000   37731.000000
# 25%           3.200000   56957.000000
# 50%           5.100000   67938.000000
# 75%           8.700000  109431.000000
# max          13.000000  156000.000000

# %%
# infornmation about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 660.0 bytes

# %%
print(df.columns)
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
# to check if dataset has any NaN values or any missing values
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sns.pairplot(df)
plt.savefig('Mygraph.jpg')

# %%
plt.xlabel('EXPERIENCE')
plt.ylabel('SALARY')
plt.title('YRS OF EXP vs SALARY')
plt.plot(df)

# %%
# add a new column with constant value
df['dummy'] = 100

# add a column named bonus
df['Bonus'] = df['Salary'] +(df['Salary']*0.10)

# add a column to total salary
df['Total_Salary'] = df['Salary'] + df['Bonus']

# %%
df.head()
# Out:
#    YearsExperience  Salary  dummy    Bonus  Total_Salary
# 0              1.1   39343    100  43277.3       82620.3
# 1              1.3   46205    100  50825.5       97030.5
# 2              1.5   37731    100  41504.1       79235.1
# 3              2.0   43525    100  47877.5       91402.5
# 4              2.2   39891    100  43880.1       83771.1
